# %% [markdown]
# # TF-IDF model with disease page rank values
#
# The code below uses previusly generated page rank scores for a disease-phenotype network to calculate new values based on a TF-IDF model. Instead of using frequency, the page rank scores are instead utilized to both consider the importance of highly connected phenotypes plus highly specific phenotypes. The tf-idf sum for a single disease is the total of tf-idf scores for it's corresponding phenotypes, and vice versa for a single phenotype.

# %%
import pandas as pd
from py2neo import Graph
from py2neo import Node

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
from py2neo import Database
db = Database("bolt://disease.ncats.io:80")
graph = db.default_graph

# %%
#creating a new dataframe that merges the page_rank values with disease information
weights = pd.read_csv("page_rank_weights.csv")

# %%
query = """match (n:S_GARD)--(d:DATA)  with n, d 
            match p =(n)-[:R_rel{name:"has_phenotype"}]
            -(s:S_HP)--(:DATA) return ID(n), n.N_Name, n.I_CODE, count(s)"""
d = graph.run(query).data()

# %%
diseases = pd.DataFrame.from_dict(d)
diseases.head()
# Out:
#    ID(n)  count(s)                                           n.I_CODE  \
# 0      1        16  [GARD:0000001, OMIM:603358, ORPHA:53693, ORPHA...
# 1      3        49  [GARD:0000003, OMIM:200110, ORPHA:920, ORPHANE...
# 2      7        14  [GARD:0000005, OMIM:200100, ORPHA:14, ORPHANET...
# 3     11        29  [GARD:0000007, OMIM:102370, ORPHA:969, ORPHANE...
# 4     15         9                        [GARD:0000011, OMIM:104290]
#
#                                             n.N_Name
# 0  [GRACILE SYNDROME, FLNMS, FINNISH LACTIC ACIDO...
# 1  [ABLEPHARON MACROSTOMIA SYNDROME, AMS, CONGENI...
# 2  [ABETALIPOPROTEINEMIA, BASSEN KORNZWEIG SYNDRO...
# 3  [ACROMICRIC DYSPLASIA, ACROMICRIC SKELETAL DYS...
# 4  [ALTERNATING HEMIPLEGIA OF CHILDHOOD, ALTERNAT...

# %%
diseases = pd.merge(diseases, weights, how='inner', left_on ="ID(n)", right_on = "Node_ID")

# %%
diseases = diseases.drop(columns=["Node_ID"], )

# %%
#diseases dataframe with weights
diseases.head()
# Out:
#    ID(n)  count(s)                                           n.I_CODE  \
# 0      1        16  [GARD:0000001, OMIM:603358, ORPHA:53693, ORPHA...
# 1      3        49  [GARD:0000003, OMIM:200110, ORPHA:920, ORPHANE...
# 2      7        14  [GARD:0000005, OMIM:200100, ORPHA:14, ORPHANET...
# 3     11        29  [GARD:0000007, OMIM:102370, ORPHA:969, ORPHANE...
# 4     15         9                        [GARD:0000011, OMIM:104290]
#
#                                             n.N_Name    Weight
# 0  [GRACILE SYNDROME, FLNMS, FINNISH LACTIC ACIDO...  0.000046
# 1  [ABLEPHARON MACROSTOMIA SYNDROME, AMS, CONGENI...  0.000101
# 2  [ABETALIPOPROTEINEMIA, BASSEN KORNZWEIG SYNDRO...  0.000037
# 3  [ACROMICRIC DYSPLASIA, ACROMICRIC SKELETAL DYS...  0.000060
# 4  [ALTERNATING HEMIPLEGIA OF CHILDHOOD, ALTERNAT...  0.000023

# %%
#repeating with phenotype dataframe
query = """match (n:S_HP)--(d:DATA) with n, d 
        match p =(n)-[:R_rel{name:"has_phenotype"}]-(s:S_GARD) 
        return ID(n), n.N_Name, d.id, n.I_CODE, count(s)"""
d = graph.run(query).data()
phenotypes = pd.DataFrame.from_dict(d)

# %%
phenotypes = pd.merge(phenotypes, weights, how='inner', left_on ="ID(n)", right_on = "Node_ID")
phenotypes = phenotypes.drop(columns=["Node_ID"] )

# %%
#phenotype dataframe with weights
phenotypes.head()
# Out:
#    ID(n)  count(s)        d.id  \
# 0  82727         5  HP:0001994
# 1  98209        48  HP:0001394
# 2  59646       207  HP:0000365
# 3  75348        43  HP:0003128
# 4  78847         2  HP:0012465
#
#                                             n.I_CODE  \
# 0  [MESH:D005198, SNOMEDCT_US:236468006, UMLS:C03...
# 1  [UMLS:C0023890, MESH:D008103, SNOMEDCT_US:1994...
# 2  [HP:0008563, HP:0001754, HP:0001728, HP:000040...
# 3  [HP:0005960, HP:0003255, UMLS:C0347959, SNOMED...
# 4                        [UMLS:C4022891, HP:0012465]
#
#                                             n.N_Name    Weight
# 0  [RENAL TUBULAR FANCONI SYNDROME, 'DE TONI-FANC...  0.000022
# 1  [HEPATIC CIRRHOSIS, SCAR TISSUE REPLACES HEALT...  0.000131
# 2  [HEARING DEFECT, CONGENITAL DEAFNESS, HEARING ...  0.000470
# 3  [LACTICACIDOSIS, LACTICACIDEMIA, HYPERLACTICAC...  0.000137
# 4  [INCREASED IRON CONCENTRATION IN LIVER, INCREA...  0.000020

# %%
total_d = diseases.shape[0]
total_p = phenotypes.shape[0]

# %%
#getting the sum tf-idf scores for each disease
tf_idf_sum = []
for index, row in diseases.iterrows():
    
    #generate the phenotype dataframe for each disease with weights and counts
    query = """match (n:S_GARD)--(a:DATA) with n, a 
            match p =(n)-[:R_rel{name: 'has_phenotype'}]-(h:S_HP)--(d:DATA) 
            where ID(n) = {i} return ID(h)"""
    d_weight = row["Weight"]
    d = graph.run(query, i= row["ID(n)"]).data()
    df = pd.DataFrame.from_dict(d)
    df = pd.merge(df, phenotypes, how='inner', left_on ="ID(h)", right_on = "ID(n)")
    df = df.drop(columns=["ID(h)","d.id", "n.I_CODE", "n.N_Name"])
    
    #add column for each phenotype: tf, idf, tf-idf
    df["tf(d,f)"] = df["Weight"]*d_weight
    df["idf(d,f)"] = np.log10(total_d / df["count(s)"])
    df["tf-idf"] = df["tf(d,f)"]*df["idf(d,f)"]
    
    #get the sum of each tf-idf column and add to list
    tf_idf_sum.append(np.sum(df["tf-idf"]))
    if index%100 == 0:
        print("Phenotype df set complete!")
# Out:
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!
# Phenotype df set complete!

# %%
#final disease df
diseases["tf_idf_sum"] = tf_idf_sum
diseases.head(10)
# Out:
#    ID(n)  count(s)                                           n.I_CODE  \
# 0      1        16  [GARD:0000001, OMIM:603358, ORPHA:53693, ORPHA...
# 1      3        49  [GARD:0000003, OMIM:200110, ORPHA:920, ORPHANE...
# 2      7        14  [GARD:0000005, OMIM:200100, ORPHA:14, ORPHANET...
# 3     11        29  [GARD:0000007, OMIM:102370, ORPHA:969, ORPHANE...
# 4     15         9                        [GARD:0000011, OMIM:104290]
# 5     19        19  [GARD:0000013, OMIM:206700, ORPHA:1065, ORPHAN...
# 6     25        23  [GARD:0000019, OMIM:274270, ORPHA:1675, ORPHAN...
# 7     29        12  [GARD:0000022, OMIM:262000, ORPHA:123, ORPHANE...
# 8     31        21  [GARD:0000023, OMIM:110100, ORPHA:126, ORPHANE...
# 9     37        24  [GARD:0000028, OMIM:302380, ORPHA:1388, ORPHAN...
#
#                                             n.N_Name    Weight    tf_idf_sum
# 0  [GRACILE SYNDROME, FLNMS, FINNISH LACTIC ACIDO...  0.000046  1.382186e-07
# 1  [ABLEPHARON MACROSTOMIA SYNDROME, AMS, CONGENI...  0.000101  1.140221e-06
# 2  [ABETALIPOPROTEINEMIA, BASSEN KORNZWEIG SYNDRO...  0.000037  1.303226e-07
# 3  [ACROMICRIC DYSPLASIA, ACROMICRIC SKELETAL DYS...  0.000060  3.964164e-07
# 4  [ALTERNATING HEMIPLEGIA OF CHILDHOOD, ALTERNAT...  0.000023  7.009057e-08
# 5  [GILLESPIE SYNDROME, ANIRIDIA, CEREBELLAR ATAX...  0.000041  2.593402e-07
# 6  [DIHYDROPYRIMIDINE DEHYDROGENASE DEFICIENCY, D...  0.000046  3.680357e-07
# 7  [BJORNSTAD SYNDROME, BJS, PILI TORTI AND NERVE...  0.000030  9.747654e-08
# 8  [BLEPHAROPHIMOSIS-EPICANTHUS INVERSUS-PTOSIS S...  0.000046  2.400077e-07
# 9  [CATEL MANZKE SYNDROME, HYPERPHALANGY-CLINODAC...  0.000048  3.291469e-07

# %%
diseases.to_csv("GARD_TF_IDF.csv")

# %%
#getting the sum tf-idf scores for each phenotype
tf_idf_sum2 = []
for index, row in phenotypes.iterrows():
    
    #generate the disease dataframe for each phenotype with weights and counts
    query = """match (n:S_HP)--(a:DATA) with n, a
            match p =(n)-[:R_rel{name: 'has_phenotype'}]-(h:S_GARD)--(d:DATA) 
            where ID(n) = {i} return ID(h)"""
    p_weight = row["Weight"]
    d = graph.run(query, i= row["ID(n)"]).data()
    df = pd.DataFrame.from_dict(d)
    df = pd.merge(df, diseases, how='inner', left_on ="ID(h)", right_on = "ID(n)")
    df = df.drop(columns=["ID(h)", "n.I_CODE", "n.N_Name"])
    
    #add column for each diseaase: tf, idf, tf-idf
    df["tf(d,f)"] = df["Weight"]*p_weight
    df["idf(d,f)"] = np.log10(total_p / df["count(s)"])
    df["tf-idf"] = df["tf(d,f)"]*df["idf(d,f)"]
    
    #get the sum of each tf-idf column and add to list
    tf_idf_sum2.append(np.sum(df["tf-idf"]))
    if index%200 == 0:
        print("Disease df set complete!")
# Out:
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!
# Disease df set complete!

# %%
phenotypes["tf_idf_sum"] = tf_idf_sum2
phenotypes.head(10)
# Out:
#     ID(n)  count(s)        d.id  \
# 0   82727         5  HP:0001994
# 1   98209        48  HP:0001394
# 2   59646       207  HP:0000365
# 3   75348        43  HP:0003128
# 4   78847         2  HP:0012465
# 5   98159        45  HP:0001397
# 6  125687        10  HP:0100613
# 7   78855         1  HP:0012464
# 8  111594         3  HP:0004925
# 9  104771         5  HP:0003452
#
#                                             n.I_CODE  \
# 0  [MESH:D005198, SNOMEDCT_US:236468006, UMLS:C03...
# 1  [UMLS:C0023890, MESH:D008103, SNOMEDCT_US:1994...
# 2  [HP:0008563, HP:0001754, HP:0001728, HP:000040...
# 3  [HP:0005960, HP:0003255, UMLS:C0347959, SNOMED...
# 4                        [UMLS:C4022891, HP:0012465]
# 5  [HP:0002252, HP:0200121, MESH:D005234, SNOMEDC...
# 6                        [UMLS:C4022012, HP:0100613]
# 7                        [UMLS:C0919785, HP:0012464]
# 8            [HP:0004899, UMLS:C1839437, HP:0004925]
# 9  [UMLS:C0151900, SNOMEDCT_US:165624002, HP:0003...
#
#                                             n.N_Name    Weight    tf_idf_sum
# 0  [RENAL TUBULAR FANCONI SYNDROME, 'DE TONI-FANC...  0.000022  2.729152e-08
# 1  [HEPATIC CIRRHOSIS, SCAR TISSUE REPLACES HEALT...  0.000131  1.109996e-06
# 2  [HEARING DEFECT, CONGENITAL DEAFNESS, HEARING ...  0.000470  1.979341e-05
# 3  [LACTICACIDOSIS, LACTICACIDEMIA, HYPERLACTICAC...  0.000137  9.326714e-07
# 4  [INCREASED IRON CONCENTRATION IN LIVER, INCREA...  0.000020  5.927394e-09
# 5  [LIVER STEATOSIS, FATTY LIVER, FATTY INFILTRAT...  0.000126  1.005284e-06
# 6                         [DEATH IN EARLY ADULTHOOD]  0.000029  9.115299e-08
# 7                   DECREASED TRANSFERRIN SATURATION  0.000016  1.972279e-09
# 8                            CHRONIC LACTIC ACIDOSIS  0.000024  1.036932e-08
# 9                               INCREASED SERUM IRON  0.000025  1.753008e-08

# %%
phenotypes.to_csv("HP_TF_IDF.csv")

# %%
diseases = pd.read_csv("GARD_TF_IDF.csv")

# %%
diseases.sort_values(by=['Weight'], ascending=False)[:10]
# Out:
#       Unnamed: 0  ID(n)  count(s)  \
# 1214        1214   7305       218
# 493          493   3248       141
# 859          859   5266       154
# 1130        1130   6786       121
# 1155        1155   6952       115
# 984          984   6010       126
# 1641        1641   9633       140
# 10            10     39       126
# 1167        1167   7029       122
# 977          977   5978       114
#
#                                                n.I_CODE  \
# 1214  ['GARD:0007891', 'OMIM:194050', 'ORPHA:904', '...
# 493   ['GARD:0003295', 'OMIM:309000', 'ORPHA:534', '...
# 859   ['GARD:0005683', 'OMIM:270400', 'ORPHA:818', '...
# 1130  ['GARD:0007305', 'OMIM:146510', 'ORPHA:672', '...
# 1155  ['GARD:0007475', 'OMIM:176920', 'ORPHA:744', '...
# 984   ['GARD:0006457', 'OMIM:305600', 'ORPHA:2092', ...
# 1641  ['GARD:0010109', 'OMIM:122470', 'ORPHA:199', '...
# 10    ['GARD:0000029', 'OMIM:214800', 'ORPHA:138', '...
# 1167                    ['GARD:0007593', 'OMIM:180849']
# 977   ['GARD:0006425', 'OMIM:227650', 'ORPHA:84', 'O...
#
#                                                n.N_Name    Weight  tf_idf_sum
# 1214  ['WILLIAMS SYNDROME', 'WILLIAMS-BEUREN SYNDROM...  0.000452    0.000018
# 493   ['LOWE OCULOCEREBRORENAL SYNDROME', 'OCRL', 'O...  0.000305    0.000009
# 859   ['SMITH-LEMLI-OPITZ SYNDROME', 'SMITH LEMLI OP...  0.000301    0.000010
# 1130  ['PALLISTER-HALL SYNDROME', 'PHS', 'HYPOTHALAM...  0.000276    0.000006
# 1155  ['PROTEUS SYNDROME', 'HEMIHYPERTROPHY AND MACR...  0.000270    0.000006
# 984   ['FOCAL DERMAL HYPOPLASIA', 'DHOF', 'FODH', 'F...  0.000267    0.000007
# 1641  ['CORNELIA DE LANGE SYNDROME', 'BRACHMANN DE L...  0.000267    0.000008
# 10    ['CHARGE SYNDROME', 'COLOBOMA, HEART ANOMALY, ...  0.000261    0.000007
# 1167  ['RUBINSTEIN-TAYBI SYNDROME', 'RUBINSTEIN SYND...  0.000256    0.000007
# 977   ['FANCONI ANEMIA', 'FANCONI PANCYTOPENIA', "FA...  0.000254    0.000007

# %%
diseases.sort_values(by=['tf_idf_sum'], ascending=False)[:10]
# Out:
#       Unnamed: 0  ID(n)  count(s)  \
# 1214        1214   7305       218
# 859          859   5266       154
# 493          493   3248       141
# 1641        1641   9633       140
# 10            10     39       126
# 1167        1167   7029       122
# 977          977   5978       114
# 984          984   6010       126
# 1350        1350   8094       119
# 1710        1710   9927       119
#
#                                                n.I_CODE  \
# 1214  ['GARD:0007891', 'OMIM:194050', 'ORPHA:904', '...
# 859   ['GARD:0005683', 'OMIM:270400', 'ORPHA:818', '...
# 493   ['GARD:0003295', 'OMIM:309000', 'ORPHA:534', '...
# 1641  ['GARD:0010109', 'OMIM:122470', 'ORPHA:199', '...
# 10    ['GARD:0000029', 'OMIM:214800', 'ORPHA:138', '...
# 1167                    ['GARD:0007593', 'OMIM:180849']
# 977   ['GARD:0006425', 'OMIM:227650', 'ORPHA:84', 'O...
# 984   ['GARD:0006457', 'OMIM:305600', 'ORPHA:2092', ...
# 1350  ['GARD:0009146', 'OMIM:115150', 'ORPHA:1340', ...
# 1710  ['GARD:0010299', 'OMIM:611867', 'ORPHA:567', '...
#
#                                                n.N_Name    Weight  tf_idf_sum
# 1214  ['WILLIAMS SYNDROME', 'WILLIAMS-BEUREN SYNDROM...  0.000452    0.000018
# 859   ['SMITH-LEMLI-OPITZ SYNDROME', 'SMITH LEMLI OP...  0.000301    0.000010
# 493   ['LOWE OCULOCEREBRORENAL SYNDROME', 'OCRL', 'O...  0.000305    0.000009
# 1641  ['CORNELIA DE LANGE SYNDROME', 'BRACHMANN DE L...  0.000267    0.000008
# 10    ['CHARGE SYNDROME', 'COLOBOMA, HEART ANOMALY, ...  0.000261    0.000007
# 1167  ['RUBINSTEIN-TAYBI SYNDROME', 'RUBINSTEIN SYND...  0.000256    0.000007
# 977   ['FANCONI ANEMIA', 'FANCONI PANCYTOPENIA', "FA...  0.000254    0.000007
# 984   ['FOCAL DERMAL HYPOPLASIA', 'DHOF', 'FODH', 'F...  0.000267    0.000007
# 1350  ['CARDIOFACIOCUTANEOUS SYNDROME', 'CFC SYNDROM...  0.000231    0.000007
# 1710  ['22Q11.2 DELETION SYNDROME', 'CHROMOSOME 22Q1...  0.000245    0.000006

# %%
diseases.sort_values(by=['tf_idf_sum'])[:10]
# Out:
#       Unnamed: 0  ID(n)  count(s)  \
# 1406        1406   8350         1
# 1004        1004   6118         1
# 267          267   1650         1
# 994          994   6047         1
# 894          894   5431         2
# 435          435   2918         1
# 930          930   5689         1
# 680          680   4178         1
# 1355        1355   8112         2
# 1185        1185   7145         2
#
#                                                n.I_CODE  \
# 1406   ['GARD:0009303', 'OMIM:605462', 'UMLS:C1854245']
# 1004  ['GARD:0006554', 'OMIM:139393', 'ORPHA:2103', ...
# 267   ['GARD:0001481', 'OMIM:142340', 'ORPHA:2140', ...
# 994                     ['GARD:0006485', 'OMIM:137245']
# 894   ['GARD:0005836', 'OMIM:609135', 'ORPHA:88', 'O...
# 435       ['GARD:0002929', 'ORPHA:440', 'ORPHANET:440']
# 930   ['GARD:0006102', 'OMIM:139393', 'ORPHA:2932', ...
# 680       ['GARD:0004484', 'ORPHA:244', 'ORPHANET:244']
# 1355                    ['GARD:0009159', 'OMIM:300018']
# 1185  ['GARD:0007721', 'OMIM:300813', 'ORPHA:3273', ...
#
#                                                n.N_Name    Weight  \
# 1406  ['BASAL CELL CARCINOMA, MULTIPLE', 'MULTIPLE B...  0.000008
# 1004  ['GUILLAIN-BARRE SYNDROME', 'ACUTE AUTOIMMUNE ...  0.000010
# 267   ['CONGENITAL DIAPHRAGMATIC HERNIA', 'CDH', 'CO...  0.000007
# 994   ['GASTRIC LYMPHOMA', 'FAMILIAL PRIMARY GASTRIC...  0.000017
# 894   ['APLASTIC ANEMIA', 'ANEMIA APLASTIC', 'APLAST...  0.000010
# 435                                HYPOSPADIAS FAMILIAL  0.000007
# 930   ['CHRONIC INFLAMMATORY DEMYELINATING POLYNEURO...  0.000023
# 680   ['PRIMARY CILIARY DYSKINESIA', 'CILIARY DYSKIN...  0.000007
# 1355           ['DOSAGE-SENSITIVE SEX REVERSAL', 'DSS']  0.000010
# 1185  ['SYNOVIAL SARCOMA', 'SYNOVIAL CELL SARCOMA', ...  0.000014
#
#         tf_idf_sum
# 1406  8.647112e-10
# 1004  9.271684e-10
# 267   1.250752e-09
# 994   1.364585e-09
# 894   1.619751e-09
# 435   2.033226e-09
# 930   2.068299e-09
# 680   2.442349e-09
# 1355  2.546163e-09
# 1185  3.805420e-09

# %%
phenotypes = pd.read_csv("HP_TF_IDF.csv")

# %%
#final phenotype df
phenotypes.sort_values(by=['Weight'], ascending = False)[:10]
# Out:
#      Unnamed: 0  ID(n)  count(s)        d.id  \
# 18           18  89585      1048  HP:0000007
# 17           17  89629       844  HP:0000006
# 127         127  66797       531  HP:0001250
# 103         103  67010       531  HP:0001249
# 53           53  66485       452  HP:0001263
# 176         176  55735       411  HP:0004322
# 173         173  68784       337  HP:0002650
# 106         106  73241       291  HP:0000639
# 64           64  66781       300  HP:0001252
# 134         134  65644       312  HP:0001290
#
#                                               n.I_CODE  \
# 18   ['HP:0001416', 'HP:0001526', 'SNOMEDCT_US:2582...
# 17   ['HP:0001463', 'HP:0001447', 'HP:0001456', 'HP...
# 127  ['HP:0002466', 'HP:0001303', 'HP:0002479', 'HP...
# 103  ['HP:0002316', 'HP:0002402', 'HP:0007154', 'HP...
# 53   ['HP:0007228', 'HP:0007174', 'HP:0001255', 'HP...
# 176  ['HP:0003501', 'HP:0001509', 'HP:0003518', 'HP...
# 173  ['HP:0003317', 'HP:0003415', 'HP:0003303', 'HP...
# 106  ['UMLS:C0028738', 'MESH:D009759', 'SNOMEDCT_US...
# 64   ['HP:0001318', 'SNOMEDCT_US:398152000', 'UMLS:...
# 134                    ['UMLS:C1858120', 'HP:0001290']
#
#                                               n.N_Name    Weight  tf_idf_sum
# 18   ['AUTOSOMAL RECESSIVE', 'AUTOSOMAL RECESSIVE F...  0.002253    0.000341
# 17   ['AUTOSOMAL DOMINANT', 'AUTOSOMAL DOMINANT TYP...  0.002004    0.000231
# 127                ['SEIZURE', 'SEIZURES', 'EPILEPSY']  0.001065    0.000102
# 103  ['INTELLECTUAL DISABILITY', 'NONPROGRESSIVE IN...  0.001026    0.000102
# 53   ['RETARDED DEVELOPMENT', 'LACK OF PSYCHOMOTOR ...  0.000848    0.000071
# 176  ['SHORT STATURE', 'DECREASED BODY HEIGHT', 'HE...  0.000798    0.000067
# 173     ['ABNORMAL CURVING OF THE SPINE', 'SCOLIOSIS']  0.000634    0.000045
# 106  ['INVOLUNTARY, RAPID, RHYTHMIC EYE MOVEMENTS',...  0.000611    0.000032
# 64   ['LOW OR WEAK MUSCLE TONE', 'MUSCLE HYPOTONIA'...  0.000595    0.000035
# 134  ['HYPOTONIA, GENERALIZED', 'GENERALIZED MUSCUL...  0.000583    0.000034

# %%
phenotypes.sort_values(by=['tf_idf_sum'], ascending = False)[:10]
# Out:
#      Unnamed: 0  ID(n)  count(s)        d.id  \
# 18           18  89585      1048  HP:0000007
# 17           17  89629       844  HP:0000006
# 103         103  67010       531  HP:0001249
# 127         127  66797       531  HP:0001250
# 53           53  66485       452  HP:0001263
# 176         176  55735       411  HP:0004322
# 173         173  68784       337  HP:0002650
# 64           64  66781       300  HP:0001252
# 134         134  65644       312  HP:0001290
# 106         106  73241       291  HP:0000639
#
#                                               n.I_CODE  \
# 18   ['HP:0001416', 'HP:0001526', 'SNOMEDCT_US:2582...
# 17   ['HP:0001463', 'HP:0001447', 'HP:0001456', 'HP...
# 103  ['HP:0002316', 'HP:0002402', 'HP:0007154', 'HP...
# 127  ['HP:0002466', 'HP:0001303', 'HP:0002479', 'HP...
# 53   ['HP:0007228', 'HP:0007174', 'HP:0001255', 'HP...
# 176  ['HP:0003501', 'HP:0001509', 'HP:0003518', 'HP...
# 173  ['HP:0003317', 'HP:0003415', 'HP:0003303', 'HP...
# 64   ['HP:0001318', 'SNOMEDCT_US:398152000', 'UMLS:...
# 134                    ['UMLS:C1858120', 'HP:0001290']
# 106  ['UMLS:C0028738', 'MESH:D009759', 'SNOMEDCT_US...
#
#                                               n.N_Name    Weight  tf_idf_sum
# 18   ['AUTOSOMAL RECESSIVE', 'AUTOSOMAL RECESSIVE F...  0.002253    0.000341
# 17   ['AUTOSOMAL DOMINANT', 'AUTOSOMAL DOMINANT TYP...  0.002004    0.000231
# 103  ['INTELLECTUAL DISABILITY', 'NONPROGRESSIVE IN...  0.001026    0.000102
# 127                ['SEIZURE', 'SEIZURES', 'EPILEPSY']  0.001065    0.000102
# 53   ['RETARDED DEVELOPMENT', 'LACK OF PSYCHOMOTOR ...  0.000848    0.000071
# 176  ['SHORT STATURE', 'DECREASED BODY HEIGHT', 'HE...  0.000798    0.000067
# 173     ['ABNORMAL CURVING OF THE SPINE', 'SCOLIOSIS']  0.000634    0.000045
# 64   ['LOW OR WEAK MUSCLE TONE', 'MUSCLE HYPOTONIA'...  0.000595    0.000035
# 134  ['HYPOTONIA, GENERALIZED', 'GENERALIZED MUSCUL...  0.000583    0.000034
# 106  ['INVOLUNTARY, RAPID, RHYTHMIC EYE MOVEMENTS',...  0.000611    0.000032

# %%
phenotypes.sort_values(by=['tf_idf_sum'])[:10]
# Out:
#       Unnamed: 0   ID(n)  count(s)                                       d.id  \
# 2331        2331   77273         1                                 HP:0001118
# 5301        5301  102953         1                                 HP:0004854
# 1852        1852   58776         1                                 HP:0006311
# 3790        3790   66181         1                                 HP:0100959
# 4216        4216  111104         1                                 HP:0007404
# 4553        4553  116503         1                                 HP:0008005
# 3998        3998   98087         1                                 HP:0006779
# 5651        5651   50367         1                                 HP:0007690
# 6178        6178   51963         1  http://purl.obolibrary.org/obo/HP_0025355
# 3001        3001  116573         1                                 HP:0008007
#
#                                                n.I_CODE  \
# 2331  ['UMLS:C0302254', 'SNOMEDCT_US:399336001', 'HP...
# 5301                    ['UMLS:C1839167', 'HP:0004854']
# 1852                    ['UMLS:C4025065', 'HP:0006311']
# 3790                    ['UMLS:C4020919', 'HP:0100959']
# 4216    ['UMLS:C1833030', 'MESH:C563422', 'HP:0007404']
# 4553                    ['UMLS:C1611195', 'HP:0008005']
# 3998  ['SNOMEDCT_US:404053004', 'SNOMEDCT_US:6344900...
# 5651  ['UMLS:C0271285', 'SNOMEDCT_US:32935005', 'HP:...
# 6178                                         HP:0025355
# 3001  ['UMLS:C1533041', 'SNOMEDCT_US:415176004', 'HP...
#
#                                                n.N_Name    Weight  \
# 2331                                  JUVENILE CATARACT  0.000012
# 5301                      INTERMITTENT THROMBOCYTOPENIA  0.000013
# 1852  ['DECREASED WIDTH OF ALL TEETH', 'DECREASED TO...  0.000012
# 3790  ['DENSE METAPHYSEAL LINES', 'TRANSVERSE METAPH...  0.000013
# 4216          NONEPIDERMOLYTIC PALMOPLANTAR KERATODERMA  0.000012
# 4553                       CONGENITAL CORNEAL DYSTROPHY  0.000014
# 3998                          ALVEOLAR RHABDOMYOSARCOMA  0.000016
# 5651              MAP-DOT-FINGERPRINT CORNEAL DYSTROPHY  0.000013
# 6178                    RETINAL ARTERIAL MACROANEURYSMS  0.000012
# 3001                        PRIMARY CONGENITAL GLAUCOMA  0.000018
#
#         tf_idf_sum
# 2331  5.061877e-10
# 5301  5.521535e-10
# 1852  5.777107e-10
# 3790  6.157180e-10
# 4216  6.297146e-10
# 4553  6.308429e-10
# 3998  6.470843e-10
# 5651  6.509786e-10
# 6178  6.702058e-10
# 3001  6.831869e-10
